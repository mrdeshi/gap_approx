# %%
from instance import InstanceRestrictedAssignment
from instances_template import pick_one_instance
from covering import Covering
import numpy as np


#n, m, M = pick_one_instance("1034/1020")
# M = np.array([[3, 6, 12, 24, 17, 33, 66, 132, 264, 528, 160, 640, 576, 320, 288],
#               [3, 6, 12, 24, 17, 33, 66, 132, 264, 528, 160, 640, 576, 320, 288]
#             ])
#
# n = M.shape[1]
# m = M.shape[0]
# instance = InstanceRestrictedAssignment(n, m, generate=False, M = M)
instance = Covering(3,15, [1, 6, 12, 24, 17, 33, 66, 132, 264, 528, 160, 640, 576, 320, 288])
#instance = Covering(3,15, [1, 6, 11, 24, 17, 33, 66, 132, 264, 528, 160, 640, 576, 320, 288])

#instance = Covering(2,4, [3,1,1,2]) 
#instance = Covering(2,7, [2,11,27,5,31,35,11]) #half integer solution, intger +1 2**4-1 machines
#instance = Covering(2,8, [3,1,11,25,4,34,32,11]) # 3**2-1 machines

def print_result(d):
    if(not d):
       print("not feasible")
    for k in d.keys():
        if (d.get(k)!=0):
            print("subset=",k,"ibrid machine=",d.get(k))



makespan = 1026

print("------LINEAR MAKESPAN SOLUTION------")
print(makespan)
a,b = instance.is_feasible(makespan)
print_result(b)

print("\n------HALF-INTEGRAL MAKESPAN SOLUTION------")
print(makespan)
c,d = instance.is_half_integral_feasible(makespan)
print_result(d)

#print(f"Solve: {instance.solve(makespan)}")

sol, C_max = instance.opt_IP()
print(f"\n-------IP OPTIMAL BINARY SEARCH-------\nT={C_max}\n{sol}")

#C_max_h, sol_h  = instance.half_integral_opt_LP()
#print(f"Optimal C_max half: {C_max_h}, solutions {sol_h}")

print("\n-------LP OPTIMAL BINARY SEARCH LINEAR-------")
C_max_LP = instance.opt_LP(verbose=True, C_max=C_max)
print("T=",C_max_LP[0])
print_result(C_max_LP[1])
#
# Out:
# ------LINEAR MAKESPAN SOLUTION------
# 1026
# subset= (6, 11, 13) ibrid machine= 0.7058823529411765
# subset= (0, 3, 7, 12, 14) ibrid machine= 0.05882352941176472
# subset= (1, 3, 7, 12, 14) ibrid machine= 0.32352941176470584
# subset= (4, 5, 9, 10, 14) ibrid machine= 0.5882352941176471
# subset= (0, 1, 2, 8, 10, 12) ibrid machine= 0.4117647058823529
# subset= (0, 1, 3, 5, 11, 13) ibrid machine= 0.11764705882352941
# subset= (0, 2, 4, 5, 11, 13) ibrid machine= 0.17647058823529405
# subset= (0, 4, 5, 7, 8, 12) ibrid machine= 0.08823529411764708
# subset= (2, 3, 6, 7, 8, 9) ibrid machine= 0.38235294117647056
# subset= (0, 1, 3, 4, 7, 8, 12) ibrid machine= 0.11764705882352941
# subset= (0, 1, 2, 4, 5, 7, 9, 14) ibrid machine= 0.02941176470588236
#
# ------HALF-INTEGRAL MAKESPAN SOLUTION------
# 1026
# subset= (6, 11, 13) ibrid machine= 1.0
# subset= (0, 3, 8, 10, 12) ibrid machine= 0.5
# subset= (4, 5, 9, 10, 14) ibrid machine= 0.5
# subset= (0, 1, 2, 5, 7, 8, 12) ibrid machine= 0.5
# subset= (0, 1, 2, 3, 4, 7, 9, 14) ibrid machine= 0.5
#
# -------IP OPTIMAL BINARY SEARCH-------
# T=1024.0
# [2, 2, 0, 2, 0, 0, 2, 2, 2, 2, 1, 0, 1, 0, 1]
#
# -------LP OPTIMAL BINARY SEARCH LINEAR-------
# LP feasible for T=1023.0
# T= 1023.0
# subset= (0, 2, 9, 10, 13) ibrid machine= 0.5
# subset= (0, 3, 7, 12, 14) ibrid machine= 0.5
# subset= (1, 3, 5, 11, 13) ibrid machine= 0.5
# subset= (1, 4, 8, 10, 12) ibrid machine= 0.5
# subset= (2, 4, 6, 11, 14) ibrid machine= 0.5
# subset= (5, 6, 7, 8, 9) ibrid machine= 0.5

# %%
for i in range(2,10):
    for j in range(2,10):
        for k in range(2,10):
            instance = Covering(2,6, [i,j,1,k,7,1])
            sol, C_max = instance.opt_IP()
            C_max_h, sol_h  = instance.half_integral_opt_LP()
            if(C_max_h != C_max):
                print("FOUND")

# %%
for i in range(0,25):
    instance = Covering(3,15, [1, 6, 11, 25, 17, 33, 66, 132, 264, 528, 160, 640, 576, 320, 288])

    makespan = 1024

    #print(f"Optimal C_max Linear: {instance.is_feasible(makespan)}")


    ##print(f"Solve: {instance.solve(makespan)}")

    sol, C_max = instance.opt_IP()
    ##print(f"Optimal INTEGER C_max: {C_max}, solutions {sol}")

    #C_max_h, sol_h  = instance.half_integral_opt_LP()
    #print(f"Optimal C_max half: {C_max_h}, solutions {sol_h}")

    C_max_LP = instance.opt_LP(verbose=True, C_max=C_max)
    ##print(f"Optimal C_max LP relaxation: {C_max_LP[0]} , solutions {C_max_LP[0]}")
    #print(C_max_LP[0]==C_max)
    if(C_max != C_max_LP[0]):
        print("DIFFERENT ",i)
    print('NEXT')
